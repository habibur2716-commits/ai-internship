# %%
age = 20

if age >= 18:
    print("Adult")
elif age >= 13:
    print("Teenager")
else:
    print("Child")

# %%
for i in range(1, 27):
    print(i)

# %%
count = 0
while count < 5:
    print(count)
    count = count + 1

# %%
squares = [x*x for x in range(1, 6)]
print(squares)
