# %%
import math
print(math.sqrt(16))
print(math.pi)

# %%
from random import randint
print(randint(1, 10))

# %%
import mymodule
print(mymodule.say_hello("habib"))
print(mymodule.add_numbers(10, 20))
