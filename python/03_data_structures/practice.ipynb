# %%
fruits = ["apple", "banana", "mango"]
fruits.append("orange")
print(fruits)
# Out:
# ['apple', 'banana', 'mango', 'orange']

# %%
coordinates = (10, 20)
print(coordinates[0], coordinates[1])
# Out:
# 10 20

# %%
person = {"name": "Ali", "age": 22, "city": "Lahore"}
person["email"] = "ali@example.com"
print(person)
# Out:
# {'name': 'Ali', 'age': 22, 'city': 'Lahore', 'email': 'ali@example.com'}

# %%
numbers = {1, 2, 2, 3, 3, 3}
print(numbers)
# Out:
# {1, 2, 3}
