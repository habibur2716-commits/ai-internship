# %%
with open("data.txt", "w") as file:
    file.write("Hello, this is my practice file!")
print("File is written")
# Out:
# File is written

# %%
with open("data.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# Hello, this is my practice file!

# %%
try:
    with open("spidy.txt", "r") as file:
        content = file.read()
except FileNotFoundError:
    print("File not found!")
# Out:
# File not found!

# %%
try:
    num = int("hello")
except ValueError:
    print("this is not valid number!")
finally:
    print("Work is complete")
# Out:
# this is not valid number!
# Work is complete
